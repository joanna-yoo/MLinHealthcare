# %%
import pandas as pd
import sys
vdj = pd.read_csv("databases/vdjdb-2018-06-04/vdjdb_full.txt", sep="\t")
# Out:
# /Users/bonsai/anaconda3/envs/env/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
sys.getsizeof(vdj) / 1024 / 1024 ## Roughly 54 MB
# Out:
# 54.1025505065918

# %%
vdj.shape
# Out:
# (28161, 34)

# %%
vdj.columns
# Out:
# Index(['cdr3.alpha', 'v.alpha', 'j.alpha', 'cdr3.beta', 'v.beta', 'd.beta',
#        'j.beta', 'species', 'mhc.a', 'mhc.b', 'mhc.class', 'antigen.epitope',
#        'antigen.gene', 'antigen.species', 'reference.id',
#        'method.identification', 'method.frequency', 'method.singlecell',
#        'method.sequencing', 'method.verification', 'meta.study.id',
#        'meta.cell.subset', 'meta.subject.cohort', 'meta.subject.id',
#        'meta.replica.id', 'meta.clone.id', 'meta.epitope.id', 'meta.tissue',
#        'meta.donor.MHC', 'meta.donor.MHC.method', 'meta.structure.id',
#        'cdr3fix.alpha', 'cdr3fix.beta', 'vdjdb.score'],
#       dtype='object')

# %%
vdj['vdjdb.score'].unique() ## confidence scores are 0, 1, 2, 3
# Out:
# array([1, 0, 3, 2])

# %%
len(vdj['cdr3.alpha'].unique())
# Out:
# 7281

# %%
len(vdj['cdr3.beta'].unique())
# Out:
# 17494

# %%
len(vdj['v.beta'].unique())
# Out:
# 77

# %%
vdj['j.beta'].unique()
# Out:
# array([nan, 'TRBJ2-7*01', 'TRBJ2-1*01', 'TRBJ2-2*01', 'TRBJ1-2*01',
#        'TRBJ2-5*01', 'TRBJ1-5*01', 'TRBJ2-3*01', 'TRBJ1-6*01',
#        'TRBJ1-1*01', 'TRBJ1-3*01', 'TRBJ2-4*01', 'TRBJ1-4*01',
#        'TRBJ2-6*01', 'TRBJ1-6*02', 'TRBJ1-4*02', 'TRBJ1-5*02'],
#       dtype=object)

# %%
vdj.head(100)
# Out:
#        cdr3.alpha        v.alpha    j.alpha        cdr3.beta       v.beta  \
# 0      CAVTDDKIIF    TRAV12-2*01  TRAJ30*01              NaN          NaN
# 1   CAVDSGGYQKVTF    TRAV12-2*01  TRAJ13*01              NaN          NaN
# 2      CAGGDDKIIF    TRAV12-2*01  TRAJ30*01              NaN          NaN
# 3      CAVKDARLMF    TRAV12-2*01  TRAJ31*01              NaN          NaN
# 4      CAVGSDKIIF    TRAV12-2*01  TRAJ30*01              NaN          NaN
# 5      CAVSDARLMF    TRAV12-2*01  TRAJ31*01              NaN          NaN
# 6      CAAFDDKIIF    TRAV12-2*01  TRAJ30*01              NaN          NaN
# 7      CAASASKLIF  TRAV29/DV5*01   TRAJ4*01              NaN          NaN
# 8    CAVDTNAGKSTF    TRAV12-2*01  TRAJ27*01              NaN          NaN
# 9      CAAVNNDMRF    TRAV13-1*01  TRAJ43*01              NaN          NaN
# 10     CAVGDARLMF    TRAV12-2*01  TRAJ43*01              NaN          NaN
# 11     CAANNARLMF    TRAV12-2*01  TRAJ31*01              NaN          NaN
# 12     CAVNGNKLVF    TRAV12-2*01  TRAJ47*01              NaN          NaN
# 13     CAVGDDKIIF    TRAV12-2*01  TRAJ30*01              NaN          NaN
# 14   CAVNSNTDKLIF    TRAV12-2*01  TRAJ34*01              NaN          NaN
# 15   CAVNSNTDKLIF    TRAV12-2*01  TRAJ34*01              NaN          NaN
# 16     CAATDDKIIF    TRAV12-2*01  TRAJ30*01              NaN          NaN
# 17    CAVNDKYKLSF    TRAV12-2*01  TRAJ20*01              NaN          NaN
# 18     CAGSGDKLIF    TRAV12-2*01  TRAJ34*01              NaN          NaN
# 19   CAEEGRGNDMRF    TRAV12-2*01  TRAJ43*01              NaN          NaN
# 20    CAVSKDDKIIF    TRAV12-2*01  TRAJ30*01              NaN          NaN
# 21     CASRDDKIIF    TRAV12-2*01  TRAJ30*01              NaN          NaN
# 22     CAVTPDKVIF    TRAV12-2*01  TRAJ50*01              NaN          NaN
# 23  CAVTSDSWGKLQF    TRAV12-2*01  TRAJ24*01              NaN          NaN
# 24     CAVVDDKLIF    TRAV12-2*01   TRAJ4*01              NaN          NaN
# 25     CAVRDDKIIF       TRAV3*01  TRAJ30*01              NaN          NaN
# 26     CATSNNRLAF    TRAV12-2*01   TRAJ7*01              NaN          NaN
# 27     CVVNADDMRF    TRAV12-1*01  TRAJ43*01              NaN          NaN
# 28      CGVDDKIIF      TRAV34*01  TRAJ30*01              NaN          NaN
# 29    CVVTGTYKYIF    TRAV12-1*01  TRAJ40*01              NaN          NaN
# ..            ...            ...        ...              ...          ...
# 70            NaN            NaN        NaN    CASSLGVDAEQFF  TRBV13-1*01
# 71            NaN            NaN        NaN    CASSLGVGDTQYF  TRBV13-1*01
# 72            NaN            NaN        NaN    CASSFGVNSDYTF  TRBV13-1*01
# 73            NaN            NaN        NaN    CASSFGTGGRVFF  TRBV13-1*01
# 74            NaN            NaN        NaN    CASSHGTGAPQYF  TRBV13-1*01
# 75            NaN            NaN        NaN    CASSFGVSYEQYF  TRBV13-1*01
# 76            NaN            NaN        NaN    CASSLGVGDTQYF  TRBV13-1*01
# 77            NaN            NaN        NaN    CASSWGTGNTQYF  TRBV13-1*01
# 78            NaN            NaN        NaN    CASSLGTGGKQFF  TRBV13-1*01
# 79            NaN            NaN        NaN    CASSQGIGAEQFF  TRBV13-1*01
# 80            NaN            NaN        NaN    CASSFGVSYEQYF  TRBV13-1*01
# 81            NaN            NaN        NaN    CASSFGVNSDYTF  TRBV13-1*01
# 82            NaN            NaN        NaN    CASSPGVGTEVFF  TRBV13-1*01
# 83            NaN            NaN        NaN    CASSLGVGDTQYF  TRBV13-1*01
# 84            NaN            NaN        NaN    CASSFGTGGRVFF  TRBV13-1*01
# 85            NaN            NaN        NaN    CASSPGTGVEQYF  TRBV13-1*01
# 86            NaN            NaN        NaN    CASSFGVSYEQYF  TRBV13-1*01
# 87            NaN            NaN        NaN    CASSPGTGQAPLF  TRBV13-1*01
# 88            NaN            NaN        NaN    CASSFGVNSDYTF  TRBV13-1*01
# 89            NaN            NaN        NaN    CASSFHISYEQYF  TRBV13-1*01
# 90            NaN            NaN        NaN   CASSFRDSGNTLYF  TRBV13-1*01
# 91            NaN            NaN        NaN  CASSFRDGTNTEVFF  TRBV13-1*01
# 92            NaN            NaN        NaN   CASSFRDSGNTLYF  TRBV13-1*01
# 93            NaN            NaN        NaN  CASSLRDGSNQAPLF  TRBV13-1*01
# 94            NaN            NaN        NaN  CASSLFRASAETLYF    TRBV24*01
# 95            NaN            NaN        NaN  CASSPHRASQNTLYF  TRBV12-1*01
# 96            NaN            NaN        NaN  CASSLFRANTGQLYF    TRBV24*01
# 97            NaN            NaN        NaN  CASSPYRGGNQAPLF  TRBV12-1*01
# 98            NaN            NaN        NaN  CASSLSRASQNTLYF    TRBV26*01
# 99            NaN            NaN        NaN  CASSPFRGSQNTLYF  TRBV12-1*01
#
#    d.beta      j.beta      species     mhc.a mhc.b     ...      \
# 0     NaN         NaN  HomoSapiens  HLA-A*02   B2M     ...
# 1     NaN         NaN  HomoSapiens  HLA-A*02   B2M     ...
# 2     NaN         NaN  HomoSapiens  HLA-A*02   B2M     ...
# 3     NaN         NaN  HomoSapiens  HLA-A*02   B2M     ...
# 4     NaN         NaN  HomoSapiens  HLA-A*02   B2M     ...
# 5     NaN         NaN  HomoSapiens  HLA-A*02   B2M     ...
# 6     NaN         NaN  HomoSapiens  HLA-A*02   B2M     ...
# 7     NaN         NaN  HomoSapiens  HLA-A*02   B2M     ...
# 8     NaN         NaN  HomoSapiens  HLA-A*02   B2M     ...
# 9     NaN         NaN  HomoSapiens  HLA-A*02   B2M     ...
# 10    NaN         NaN  HomoSapiens  HLA-A*02   B2M     ...
# 11    NaN         NaN  HomoSapiens  HLA-A*02   B2M     ...
# 12    NaN         NaN  HomoSapiens  HLA-A*02   B2M     ...
# 13    NaN         NaN  HomoSapiens  HLA-A*02   B2M     ...
# 14    NaN         NaN  HomoSapiens  HLA-A*02   B2M     ...
# 15    NaN         NaN  HomoSapiens  HLA-A*02   B2M     ...
# 16    NaN         NaN  HomoSapiens  HLA-A*02   B2M     ...
# 17    NaN         NaN  HomoSapiens  HLA-A*02   B2M     ...
# 18    NaN         NaN  HomoSapiens  HLA-A*02   B2M     ...
# 19    NaN         NaN  HomoSapiens  HLA-A*02   B2M     ...
# 20    NaN         NaN  HomoSapiens  HLA-A*02   B2M     ...
# 21    NaN         NaN  HomoSapiens  HLA-A*02   B2M     ...
# 22    NaN         NaN  HomoSapiens  HLA-A*02   B2M     ...
# 23    NaN         NaN  HomoSapiens  HLA-A*02   B2M     ...
# 24    NaN         NaN  HomoSapiens  HLA-A*02   B2M     ...
# 25    NaN         NaN  HomoSapiens  HLA-A*02   B2M     ...
# 26    NaN         NaN  HomoSapiens  HLA-A*02   B2M     ...
# 27    NaN         NaN  HomoSapiens  HLA-A*02   B2M     ...
# 28    NaN         NaN  HomoSapiens  HLA-A*02   B2M     ...
# 29    NaN         NaN  HomoSapiens  HLA-A*02   B2M     ...
# ..    ...         ...          ...       ...   ...     ...
# 70    NaN  TRBJ2-1*01  MusMusculus     H-2Kb   B2M     ...
# 71    NaN  TRBJ2-5*01  MusMusculus     H-2Kb   B2M     ...
# 72    NaN  TRBJ1-2*01  MusMusculus     H-2Kb   B2M     ...
# 73    NaN  TRBJ1-1*01  MusMusculus     H-2Kb   B2M     ...
# 74    NaN  TRBJ2-5*01  MusMusculus     H-2Kb   B2M     ...
# 75    NaN  TRBJ2-1*01  MusMusculus     H-2Kb   B2M     ...
# 76    NaN  TRBJ2-5*01  MusMusculus     H-2Kb   B2M     ...
# 77    NaN  TRBJ2-5*01  MusMusculus     H-2Kb   B2M     ...
# 78    NaN  TRBJ2-1*01  MusMusculus     H-2Kb   B2M     ...
# 79    NaN  TRBJ2-1*01  MusMusculus     H-2Kb   B2M     ...
# 80    NaN  TRBJ2-1*01  MusMusculus     H-2Kb   B2M     ...
# 81    NaN  TRBJ1-2*01  MusMusculus     H-2Kb   B2M     ...
# 82    NaN  TRBJ1-1*01  MusMusculus     H-2Kb   B2M     ...
# 83    NaN  TRBJ2-5*01  MusMusculus     H-2Kb   B2M     ...
# 84    NaN  TRBJ1-1*01  MusMusculus     H-2Kb   B2M     ...
# 85    NaN  TRBJ2-1*01  MusMusculus     H-2Kb   B2M     ...
# 86    NaN  TRBJ2-1*01  MusMusculus     H-2Kb   B2M     ...
# 87    NaN  TRBJ1-5*01  MusMusculus     H-2Kb   B2M     ...
# 88    NaN  TRBJ1-2*01  MusMusculus     H-2Kb   B2M     ...
# 89    NaN  TRBJ2-1*01  MusMusculus     H-2Kb   B2M     ...
# 90    NaN  TRBJ1-3*01  MusMusculus     H-2Kb   B2M     ...
# 91    NaN  TRBJ1-1*01  MusMusculus     H-2Kb   B2M     ...
# 92    NaN  TRBJ1-3*01  MusMusculus     H-2Kb   B2M     ...
# 93    NaN  TRBJ1-5*01  MusMusculus     H-2Kb   B2M     ...
# 94    NaN  TRBJ2-3*01  MusMusculus     H-2Kb   B2M     ...
# 95    NaN  TRBJ2-4*01  MusMusculus     H-2Kb   B2M     ...
# 96    NaN  TRBJ2-2*01  MusMusculus     H-2Kb   B2M     ...
# 97    NaN  TRBJ1-5*01  MusMusculus     H-2Kb   B2M     ...
# 98    NaN  TRBJ2-4*01  MusMusculus     H-2Kb   B2M     ...
# 99    NaN  TRBJ2-4*01  MusMusculus     H-2Kb   B2M     ...
#
#    meta.replica.id meta.clone.id meta.epitope.id meta.tissue meta.donor.MHC  \
# 0              NaN           NaN             NaN         NaN            NaN
# 1              NaN           NaN             NaN         NaN            NaN
# 2              NaN           NaN             NaN         NaN            NaN
# 3              NaN           NaN             NaN         NaN            NaN
# 4              NaN           NaN             NaN         NaN            NaN
# 5              NaN           NaN             NaN         NaN            NaN
# 6              NaN           NaN             NaN         NaN            NaN
# 7              NaN           NaN             NaN         NaN            NaN
# 8              NaN           NaN             NaN         NaN            NaN
# 9              NaN           NaN             NaN         NaN            NaN
# 10             NaN           NaN             NaN         NaN            NaN
# 11             NaN           NaN             NaN         NaN            NaN
# 12             NaN           NaN             NaN         NaN            NaN
# 13             NaN           NaN             NaN         NaN            NaN
# 14             NaN           NaN             NaN         NaN            NaN
# 15             NaN           NaN             NaN         NaN            NaN
# 16             NaN           NaN             NaN         NaN            NaN
# 17             NaN           NaN             NaN         NaN            NaN
# 18             NaN           NaN             NaN         NaN            NaN
# 19             NaN           NaN             NaN         NaN            NaN
# 20             NaN           NaN             NaN         NaN            NaN
# 21             NaN           NaN             NaN         NaN            NaN
# 22             NaN           NaN             NaN         NaN            NaN
# 23             NaN           NaN             NaN         NaN            NaN
# 24             NaN           NaN             NaN         NaN            NaN
# 25             NaN           NaN             NaN         NaN            NaN
# 26             NaN           NaN             NaN         NaN            NaN
# 27             NaN           NaN             NaN         NaN            NaN
# 28             NaN           NaN             NaN         NaN            NaN
# 29             NaN           NaN             NaN         NaN            NaN
# ..             ...           ...             ...         ...            ...
# 70             NaN           NaN         NP52-59      spleen            NaN
# 71             NaN           NaN         NP52-59      spleen            NaN
# 72             NaN           NaN         NP52-59      spleen            NaN
# 73             NaN           NaN         NP52-59      spleen            NaN
# 74             NaN           NaN         NP52-59      spleen            NaN
# 75             NaN           NaN         NP52-59      spleen            NaN
# 76             NaN           NaN         NP52-59      spleen            NaN
# 77             NaN           NaN         NP52-59      spleen            NaN
# 78             NaN           NaN         NP52-59      spleen            NaN
# 79             NaN           NaN         NP52-59      spleen            NaN
# 80             NaN           NaN         NP52-59      spleen            NaN
# 81             NaN           NaN         NP52-59      spleen            NaN
# 82             NaN           NaN         NP52-59      spleen            NaN
# 83             NaN           NaN         NP52-59      spleen            NaN
# 84             NaN           NaN         NP52-59      spleen            NaN
# 85             NaN           NaN         NP52-59      spleen            NaN
# 86             NaN           NaN         NP52-59      spleen            NaN
# 87             NaN           NaN         NP52-59      spleen            NaN
# 88             NaN           NaN         NP52-59      spleen            NaN
# 89             NaN           NaN         NP52-59      spleen            NaN
# 90             NaN           NaN              K6      spleen            NaN
# 91             NaN           NaN              K6      spleen            NaN
# 92             NaN           NaN              K6      spleen            NaN
# 93             NaN           NaN              K6      spleen            NaN
# 94             NaN           NaN              E6      spleen            NaN
# 95             NaN           NaN              E6      spleen            NaN
# 96             NaN           NaN              E6      spleen            NaN
# 97             NaN           NaN              E6      spleen            NaN
# 98             NaN           NaN              E6      spleen            NaN
# 99             NaN           NaN              E6      spleen            NaN
#
#    meta.donor.MHC.method meta.structure.id  \
# 0                    NaN               NaN
# 1                    NaN               NaN
# 2                    NaN               NaN
# 3                    NaN               NaN
# 4                    NaN               NaN
# 5                    NaN               NaN
# 6                    NaN               NaN
# 7                    NaN               NaN
# 8                    NaN               NaN
# 9                    NaN               NaN
# 10                   NaN               NaN
# 11                   NaN               NaN
# 12                   NaN               NaN
# 13                   NaN               NaN
# 14                   NaN               NaN
# 15                   NaN               NaN
# 16                   NaN               NaN
# 17                   NaN               NaN
# 18                   NaN               NaN
# 19                   NaN               NaN
# 20                   NaN               NaN
# 21                   NaN               NaN
# 22                   NaN               NaN
# 23                   NaN               NaN
# 24                   NaN               NaN
# 25                   NaN               NaN
# 26                   NaN               NaN
# 27                   NaN               NaN
# 28                   NaN               NaN
# 29                   NaN               NaN
# ..                   ...               ...
# 70                   NaN               NaN
# 71                   NaN               NaN
# 72                   NaN               NaN
# 73                   NaN               NaN
# 74                   NaN               NaN
# 75                   NaN               NaN
# 76                   NaN               NaN
# 77                   NaN               NaN
# 78                   NaN               NaN
# 79                   NaN               NaN
# 80                   NaN               NaN
# 81                   NaN               NaN
# 82                   NaN               NaN
# 83                   NaN               NaN
# 84                   NaN               NaN
# 85                   NaN               NaN
# 86                   NaN               NaN
# 87                   NaN               NaN
# 88                   NaN               NaN
# 89                   NaN               NaN
# 90                   NaN               NaN
# 91                   NaN               NaN
# 92                   NaN               NaN
# 93                   NaN               NaN
# 94                   NaN               NaN
# 95                   NaN               NaN
# 96                   NaN               NaN
# 97                   NaN               NaN
# 98                   NaN               NaN
# 99                   NaN               NaN
#
#                                         cdr3fix.alpha  \
# 0   {"cdr3": "CAVTDDKIIF", "cdr3_old": "CAVTDDKIIF...
# 1   {"cdr3": "CAVDSGGYQKVTF", "cdr3_old": "CAVDSGG...
# 2   {"cdr3": "CAGGDDKIIF", "cdr3_old": "CAGGDDKIIF...
# 3   {"cdr3": "CAVKDARLMF", "cdr3_old": "CAVKDARLMF...
# 4   {"cdr3": "CAVGSDKIIF", "cdr3_old": "CAVGSDKIIF...
# 5   {"cdr3": "CAVSDARLMF", "cdr3_old": "CAVSDARLMF...
# 6   {"cdr3": "CAAFDDKIIF", "cdr3_old": "CAAFDDKIIF...
# 7   {"cdr3": "CAASASKLIF", "cdr3_old": "CAASASKLIF...
# 8   {"cdr3": "CAVDTNAGKSTF", "cdr3_old": "CAVDTNAG...
# 9   {"cdr3": "CAAVNNDMRF", "cdr3_old": "CAAVNNDMRF...
# 10  {"cdr3": "CAVGDARLMF", "cdr3_old": "CAVGDARLMF...
# 11  {"cdr3": "CAANNARLMF", "cdr3_old": "CAANNARLMF...
# 12  {"cdr3": "CAVNGNKLVF", "cdr3_old": "CAVNGNKLVF...
# 13  {"cdr3": "CAVGDDKIIF", "cdr3_old": "CAVGDDKIIF...
# 14  {"cdr3": "CAVNSNTDKLIF", "cdr3_old": "CAVNSNTD...
# 15  {"cdr3": "CAVNSNTDKLIF", "cdr3_old": "CAVNSNTD...
# 16  {"cdr3": "CAATDDKIIF", "cdr3_old": "CAATDDKIIF...
# 17  {"cdr3": "CAVNDKYKLSF", "cdr3_old": "CAVNDKYKL...
# 18  {"cdr3": "CAGSGDKLIF", "cdr3_old": "CAGSGDKLIF...
# 19  {"cdr3": "CAEEGRGNDMRF", "cdr3_old": "CAEEGRGN...
# 20  {"cdr3": "CAVSKDDKIIF", "cdr3_old": "CAVSKDDKI...
# 21  {"cdr3": "CASRDDKIIF", "cdr3_old": "CASRDDKIIF...
# 22  {"cdr3": "CAVTPDKVIF", "cdr3_old": "CAVTPDKVIF...
# 23  {"cdr3": "CAVTSDSWGKLQF", "cdr3_old": "CAVTSDS...
# 24  {"cdr3": "CAVVDDKLIF", "cdr3_old": "CAVVDDKLIF...
# 25  {"cdr3": "CAVRDDKIIF", "cdr3_old": "CAVRDDKIIF...
# 26  {"cdr3": "CATSNNRLAF", "cdr3_old": "CATSNNRLAF...
# 27  {"cdr3": "CVVNADDMRF", "cdr3_old": "CVVNADDMRF...
# 28  {"cdr3": "CGVDDKIIF", "cdr3_old": "CGVDDKIIF",...
# 29  {"cdr3": "CVVTGTYKYIF", "cdr3_old": "CVVTGTYKY...
# ..                                                ...
# 70                                                NaN
# 71                                                NaN
# 72                                                NaN
# 73                                                NaN
# 74                                                NaN
# 75                                                NaN
# 76                                                NaN
# 77                                                NaN
# 78                                                NaN
# 79                                                NaN
# 80                                                NaN
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
# 84                                                NaN
# 85                                                NaN
# 86                                                NaN
# 87                                                NaN
# 88                                                NaN
# 89                                                NaN
# 90                                                NaN
# 91                                                NaN
# 92                                                NaN
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
#                                          cdr3fix.beta vdjdb.score
# 0                                                 NaN           1
# 1                                                 NaN           0
# 2                                                 NaN           0
# 3                                                 NaN           1
# 4                                                 NaN           1
# 5                                                 NaN           0
# 6                                                 NaN           1
# 7                                                 NaN           0
# 8                                                 NaN           0
# 9                                                 NaN           0
# 10                                                NaN           0
# 11                                                NaN           0
# 12                                                NaN           0
# 13                                                NaN           1
# 14                                                NaN           0
# 15                                                NaN           0
# 16                                                NaN           0
# 17                                                NaN           0
# 18                                                NaN           0
# 19                                                NaN           0
# 20                                                NaN           0
# 21                                                NaN           0
# 22                                                NaN           0
# 23                                                NaN           0
# 24                                                NaN           0
# 25                                                NaN           0
# 26                                                NaN           0
# 27                                                NaN           0
# 28                                                NaN           0
# 29                                                NaN           1
# ..                                                ...         ...
# 70  {"cdr3": "CASSLGVDAEQFF", "cdr3_old": "CASSLGV...           2
# 71  {"cdr3": "CASSLGVGDTQYF", "cdr3_old": "CASSLGV...           2
# 72  {"cdr3": "CASSFGVNSDYTF", "cdr3_old": "CASSFGV...           3
# 73  {"cdr3": "CASSFGTGGRVFF", "cdr3_old": "CASSFGT...           2
# 74  {"cdr3": "CASSHGTGAPQYF", "cdr3_old": "CASSHGT...           2
# 75  {"cdr3": "CASSFGVSYEQYF", "cdr3_old": "CASSFGV...           3
# 76  {"cdr3": "CASSLGVGDTQYF", "cdr3_old": "CASSLGV...           2
# 77  {"cdr3": "CASSWGTGNTQYF", "cdr3_old": "CASSWGT...           2
# 78  {"cdr3": "CASSLGTGGKQFF", "cdr3_old": "CASSLGT...           2
# 79  {"cdr3": "CASSQGIGAEQFF", "cdr3_old": "CASSQGI...           2
# 80  {"cdr3": "CASSFGVSYEQYF", "cdr3_old": "CASSFGV...           3
# 81  {"cdr3": "CASSFGVNSDYTF", "cdr3_old": "CASSFGV...           3
# 82  {"cdr3": "CASSPGVGTEVFF", "cdr3_old": "CASSPGV...           2
# 83  {"cdr3": "CASSLGVGDTQYF", "cdr3_old": "CASSLGV...           2
# 84  {"cdr3": "CASSFGTGGRVFF", "cdr3_old": "CASSFGT...           2
# 85  {"cdr3": "CASSPGTGVEQYF", "cdr3_old": "CASSPGT...           3
# 86  {"cdr3": "CASSFGVSYEQYF", "cdr3_old": "CASSFGV...           3
# 87  {"cdr3": "CASSPGTGQAPLF", "cdr3_old": "CASSPGT...           2
# 88  {"cdr3": "CASSFGVNSDYTF", "cdr3_old": "CASSFGV...           3
# 89  {"cdr3": "CASSFHISYEQYF", "cdr3_old": "CASSFHI...           3
# 90  {"cdr3": "CASSFRDSGNTLYF", "cdr3_old": "CASSFR...           3
# 91  {"cdr3": "CASSFRDGTNTEVFF", "cdr3_old": "CASSF...           2
# 92  {"cdr3": "CASSFRDSGNTLYF", "cdr3_old": "CASSFR...           3
# 93  {"cdr3": "CASSLRDGSNQAPLF", "cdr3_old": "CASSL...           3
# 94  {"cdr3": "CASSLFRASAETLYF", "cdr3_old": "CASSL...           2
# 95  {"cdr3": "CASSPHRASQNTLYF", "cdr3_old": "CASSP...           2
# 96  {"cdr3": "CASSLFRANTGQLYF", "cdr3_old": "CASSL...           2
# 97  {"cdr3": "CASSPYRGGNQAPLF", "cdr3_old": "CASSP...           2
# 98  {"cdr3": "CASSLSRASQNTLYF", "cdr3_old": "CASSL...           2
# 99  {"cdr3": "CASSPFRGSQNTLYF", "cdr3_old": "CASSP...           2
#
# [100 rows x 34 columns]
